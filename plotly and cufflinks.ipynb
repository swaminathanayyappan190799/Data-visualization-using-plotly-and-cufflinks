# %%
import pandas as pd
import numpy as np
import cufflinks as cf
from plotly.offline import init_notebook_mode,download_plotlyjs,plot,iplot
# %matplotlib inline

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
x=pd.DataFrame(np.random.randn(100,4),columns=['A','B','C','D'])

# %%
x.head()
# Out:
#           A         B         C         D
# 0  0.848647 -1.410339  1.519580 -0.167365
# 1  0.446374 -0.250351  1.443809 -1.454548
# 2  0.017982 -1.685927  0.722007 -1.182203
# 3  1.292813 -0.461090  2.632781 -1.745150
# 4 -2.139523  1.624397  1.624134  0.204583

# %%
x.iplot()
# Out:
# <div>
#
#
#             <div id="4a25fe29-7a26-43df-8e41-f1619f8dfcfc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4a25fe29-7a26-43df-8e41-f1619f8dfcfc")) {
#                     Plotly.newPlot(
#                         '4a25fe29-7a26-43df-8e41-f1619f8dfcfc',
# ...

# %%
x.iplot(kind='heatmap')
# Out:
# <div>
#
#
#             <div id="6c19b57b-4376-4f97-b32b-322f69f14bb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6c19b57b-4376-4f97-b32b-322f69f14bb4")) {
#                     Plotly.newPlot(
#                         '6c19b57b-4376-4f97-b32b-322f69f14bb4',
# ...

# %%
x.iplot(kind='scatter',x='A',y='B',mode='markers')
# Out:
# <div>
#
#
#             <div id="9e579717-cac1-4b05-a8e8-1a8ba81bf628" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9e579717-cac1-4b05-a8e8-1a8ba81bf628")) {
#                     Plotly.newPlot(
#                         '9e579717-cac1-4b05-a8e8-1a8ba81bf628',
# ...

# %%
df=pd.read_csv('F:/STUDY MATERIALS/Core elective selection list/CSE-B/Core elective selection for CSE - _B_ [2017 -2021] batch VII semester.csv')

# %%
df.iplot(kind='bar',x='Elective - II  ',y='Register number')
# Out:
# <div>
#
#
#             <div id="ed7bd86e-3950-4d18-b44d-754d673e3dfd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ed7bd86e-3950-4d18-b44d-754d673e3dfd")) {
#                     Plotly.newPlot(
#                         'ed7bd86e-3950-4d18-b44d-754d673e3dfd',
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'Username', 'Name of the student ', 'Roll number ',
#        'Register number', 'Elective - II  ', 'Elective - III'],
#       dtype='object')

# %%
x.iplot(kind='surface')
# Out:
# <div>
#
#
#             <div id="8e52e402-9c40-474a-9f18-a5e9358ad480" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8e52e402-9c40-474a-9f18-a5e9358ad480")) {
#                     Plotly.newPlot(
#                         '8e52e402-9c40-474a-9f18-a5e9358ad480',
# ...
